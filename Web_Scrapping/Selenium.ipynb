# %%
# web browser automation tool which stimulates a user 
# surfing the internet

# %%
from selenium import webdriver

# %%
driver = webdriver.Safari(executable_path='/usr/bin/safaridriver')
driver
# Out:
# <selenium.webdriver.safari.webdriver.WebDriver (session="ED5DE3E4-53C9-4BC9-8AB0-6BEDC19F7D86")>

# %%
driver.get('https://codingninjas.in/')

# %%
driver.title
# Out:
# 'Coding Ninjas – Learn coding online at India’s best coding institute'

# %%
driver.back()

# %%
driver.save_screenshot('test-shot.png')
# Out:
# True

# %%
driver.page_source
# Out:
# '<html lang="en" style="--batchMonthBG: #FFEBC2; --batchCardBC: #FFEBC2; --batchMonthTC: #AC933C;"><head>\n    <meta charset="utf-8">\n    <title>Coding Ninjas – Learn coding online at India’s best coding institute</title>\n\n    <meta name="google-site-verification" content="ASe_HQRsu8j61tGt95RROjXi07M380nMuoJ0Mu9rytk">\n    <meta name="title" content="Coding Ninjas – Learn coding online at India’s best coding institute">\n    <meta property="og:title" content="Coding Ninjas – Learn coding online at India’s best coding institute">\n    <meta name="description" content="With live 1:1 mentor support, get your doubts resolved via Audio Call, Video Call and Screen Share from the Teaching Assistants at Coding Ninjas.">\n    <meta property="og:description" content="With live 1:1 mentor support, get your doubts resolved via Audio Call, Video Call and Screen Share from the Teaching Assistants at Coding Ninjas.">\n    <meta property="og:image" content="https://files.codingninjas.in/000000000
# ...

# %%
# driver.find_element_by_link_text('Explore')

# %%
# red_btn = driver.find_element_by_partial_link_text('Explore')

# %%
driver.get('https://codezen.codingninjas.com/dashboard?_ga=2.102565763.326028987.1608855834-55390402.1595270607')

# %%
# driver.find_element_by_partial_link_text('advanced-algorithms')

# %%
driver.get('https://www.google.com/')

# %%
driver.title
# Out:
# 'Google'

# %%
driver.back()

# %%
# driver object : driver.Safari()
# driver.get(url) -> open the passed url after creating driver object
# driver.back()
# driver.forward()
# driver.title()
# driver.page_source : complete web page

# More methods and properties

'''
maximize_window()
refresh()


close()
quit()

Both are similar but close will just close the current window whereas quit
will close each and every window, the instance of driver
will be destroyed
'''
# Out:
# '\nmaximize_window()\nrefresh()\n\n\nclose()\nquit()\n\nBoth are similar but close will just close the current window whereas quit\nwill close each and every window, the instance of driver\nwill be destroyed\n'

# %%
driver.get('https://www.google.com/')

# %%
# to maximize the size of the window
driver.maximize_window()

# %%
driver.refresh()

# %%
driver.current_url
# Out:
# 'https://www.google.com/'

# %%
# driver.get(driver.current_url)
driver.quit()
# Out:
# ---------------------------------------------------------------------------
# InvalidSessionIdException                 Traceback (most recent call last)
# <ipython-input-65-2bf365a7f225> in <module>
#       1 # driver.get(driver.current_url)
# ----> 2 driver.quit()
#
# ~/opt/anaconda3/lib/python3.8/site-packages/selenium/webdriver/safari/webdriver.py in quit(self)
#      73         """
#      74         try:
# ---> 75             RemoteWebDriver.quit(self)
#      76         except http_client.BadStatusLine:
#      77             pass
#
# ~/opt/anaconda3/lib/python3.8/site-packages/selenium/webdriver/remote/webdriver.py in quit(self)
#     696         """
#     697         try:
# --> 698             self.execute(Command.QUIT)
#     699         finally:
#     700             self.stop_client()
#
# ~/opt/anaconda3/lib/python3.8/site-packages/selenium/webdriver/remote/webdriver.py in execute(self, driver_command, params)
# ...

# %%
# locating the element

'''
There are some methods by which selenium help
us to extract the data

find_element_by_id()
            _by_class_name()
            _by_name()
            _by_tag_name()
            _by_xpath()

find_elements_by_class_name()

'''

driver.get('http://books.toscrape.com/')
# Out:
# ---------------------------------------------------------------------------
# InvalidSessionIdException                 Traceback (most recent call last)
# <ipython-input-63-707eb2cd4c28> in <module>
#      15 '''
#      16
# ---> 17 driver.get('http://books.toscrape.com/')
#      18
#
# ~/opt/anaconda3/lib/python3.8/site-packages/selenium/webdriver/remote/webdriver.py in get(self, url)
#     331         Loads a web page in the current browser session.
#     332         """
# --> 333         self.execute(Command.GET, {'url': url})
#     334
#     335     @property
#
# ~/opt/anaconda3/lib/python3.8/site-packages/selenium/webdriver/remote/webdriver.py in execute(self, driver_command, params)
#     319         response = self.command_executor.execute(driver_command, params)
#     320         if response:
# --> 321             self.error_handler.check_response(response)
#     322             response['value'] = self._unwrap_value(
#     323                 response.get('value', None))
#
# ...

# %%
c1 = driver.find_element_by_link_text('Music')

# %%
c1
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="ED5DE3E4-53C9-4BC9-8AB0-6BEDC19F7D86", element="node-72E8EF22-73B6-4EEB-8A1A-261AEE2AFB91")>

# %%
c1.click()

# %%
b1 = driver.find_element_by_partial_link_text('Light')

# %%
b1.click()

# %%
# driver.back()
# i1 = driver.find_element_by_class_name('image_container')

# %%
driver
# Out:
# <selenium.webdriver.safari.webdriver.WebDriver (session="ED5DE3E4-53C9-4BC9-8AB0-6BEDC19F7D86")>

# %%
# driver.current_url()
