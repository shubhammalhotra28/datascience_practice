# %%
import sys  
# !{sys.executable} -m pip install pandas
#Pandas

import pandas as pd

import numpy as np
# Out:
# ...
# WARNING: You are using pip version 20.2.2; however, version 20.3.1 is available.
# You should consider upgrading via the '/usr/local/Cellar/jupyterlab/2.2.6/libexec/bin/python3.8 -m pip install --upgrade pip' command.

# %%
# loading data

iris = pd.read_csv("https://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data")
iris
# Out:
#      5.1  3.5  1.4  0.2     Iris-setosa
# 0    4.9  3.0  1.4  0.2     Iris-setosa
# 1    4.7  3.2  1.3  0.2     Iris-setosa
# 2    4.6  3.1  1.5  0.2     Iris-setosa
# 3    5.0  3.6  1.4  0.2     Iris-setosa
# 4    5.4  3.9  1.7  0.4     Iris-setosa
# ..   ...  ...  ...  ...             ...
# 144  6.7  3.0  5.2  2.3  Iris-virginica
# 145  6.3  2.5  5.0  1.9  Iris-virginica
# 146  6.5  3.0  5.2  2.0  Iris-virginica
# 147  6.2  3.4  5.4  2.3  Iris-virginica
# 148  5.9  3.0  5.1  1.8  Iris-virginica
#
# [149 rows x 5 columns]

# %%
print(type(iris))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
df = iris.copy()

# %%
df.head(3)
# Out:
#     sl   sw   pl   pw  flower_type
# 0  4.9  3.0  1.4  0.2  Iris-setosa
# 1  4.7  3.2  1.3  0.2  Iris-setosa
# 2  4.6  3.1  1.5  0.2  Iris-setosa

# %%
df.columns = ['sl','sw','pl','pw','flower_type']

# %%
print(df.shape)
print(df.dtypes)
# Out:
# (149, 5)
# sl             float64
# sw             float64
# pl             float64
# pw             float64
# flower_type     object
# dtype: object

# %%
df.describe()
# Out:
#                sl          sw          pl          pw
# count  149.000000  149.000000  149.000000  149.000000
# mean     5.848322    3.051007    3.774497    1.205369
# std      0.828594    0.433499    1.759651    0.761292
# min      4.300000    2.000000    1.000000    0.100000
# 25%      5.100000    2.800000    1.600000    0.300000
# 50%      5.800000    3.000000    4.400000    1.300000
# 75%      6.400000    3.300000    5.100000    1.800000
# max      7.900000    4.400000    6.900000    2.500000

# %%
# df.column_name

df.sl
# Out:
# 0      4.9
# 1      4.7
# 2      4.6
# 3      5.0
# 4      5.4
#       ...
# 144    6.7
# 145    6.3
# 146    6.5
# 147    6.2
# 148    5.9
# Name: sl, Length: 149, dtype: float64

# %%
df['sl']
# Out:
# 0      4.9
# 1      4.7
# 2      4.6
# 3      5.0
# 4      5.4
#       ...
# 144    6.7
# 145    6.3
# 146    6.5
# 147    6.2
# 148    5.9
# Name: sl, Length: 149, dtype: float64

# %%
df.isnull()
# Out:
#         sl     sw     pl     pw  flower_type
# 0    False  False  False  False        False
# 1    False  False  False  False        False
# 2    False  False  False  False        False
# 3    False  False  False  False        False
# 4    False  False  False  False        False
# ..     ...    ...    ...    ...          ...
# 144  False  False  False  False        False
# 145  False  False  False  False        False
# 146  False  False  False  False        False
# 147  False  False  False  False        False
# 148  False  False  False  False        False
#
# [149 rows x 5 columns]

# %%
df.isnull().sum()
# Out:
# sl             0
# sw             0
# pl             0
# pw             0
# flower_type    0
# dtype: int64

# %%
df.iloc[1:4,2:3]
# Out:
#     pl
# 1  1.3
# 2  1.5
# 3  1.4

# %%
df.iloc[2:4,2:4]
# Out:
#     pl   pw
# 2  1.5  0.2
# 3  1.4  0.2

# %%
df.tail()
# Out:
#       sl   sw   pl   pw     flower_type
# 144  6.7  3.0  5.2  2.3  Iris-virginica
# 145  6.3  2.5  5.0  1.9  Iris-virginica
# 146  6.5  3.0  5.2  2.0  Iris-virginica
# 147  6.2  3.4  5.4  2.3  Iris-virginica
# 148  5.9  3.0  5.1  1.8  Iris-virginica

# %%
df.head()
# Out:
#     sl   sw   pl   pw  flower_type
# 0  4.9  3.0  1.4  0.2  Iris-setosa
# 1  4.7  3.2  1.3  0.2  Iris-setosa
# 2  4.6  3.1  1.5  0.2  Iris-setosa
# 3  5.0  3.6  1.4  0.2  Iris-setosa
# 4  5.4  3.9  1.7  0.4  Iris-setosa

# %%
df.drop(0,inplace = True)
df.head()
# Out:
#     sl   sw   pl   pw  flower_type
# 1  4.7  3.2  1.3  0.2  Iris-setosa
# 2  4.6  3.1  1.5  0.2  Iris-setosa
# 3  5.0  3.6  1.4  0.2  Iris-setosa
# 4  5.4  3.9  1.7  0.4  Iris-setosa
# 5  4.6  3.4  1.4  0.3  Iris-setosa

# %%
# dropping the labels
df.drop(3,inplace = True)
df.drop(2,inplace = True)
df.head()
# Out:
#     sl   sw   pl   pw  flower_type
# 1  4.7  3.2  1.3  0.2  Iris-setosa
# 4  5.4  3.9  1.7  0.4  Iris-setosa
# 5  4.6  3.4  1.4  0.3  Iris-setosa
# 6  5.0  3.4  1.5  0.2  Iris-setosa
# 7  4.4  2.9  1.4  0.2  Iris-setosa

# %%
df.index
# Out:
# Int64Index([  1,   4,   5,   6,   7,   8,   9,  10,  11,  12,
#             ...
#             139, 140, 141, 142, 143, 144, 145, 146, 147, 148],
#            dtype='int64', length=146)

# %%
# this will gve us the position 0 that is the label for 0th row
df.index[0],df.index[3]
# Out:
# (1, 6)

# %%
df.drop(df.index[0],inplace = True)
df.head()
# Out:
#     sl   sw   pl   pw  flower_type
# 4  5.4  3.9  1.7  0.4  Iris-setosa
# 5  4.6  3.4  1.4  0.3  Iris-setosa
# 6  5.0  3.4  1.5  0.2  Iris-setosa
# 7  4.4  2.9  1.4  0.2  Iris-setosa
# 8  4.9  3.1  1.5  0.1  Iris-setosa

# %%
# removing more than 1 positions together
df.drop(df.index[[0,1,2,3]],inplace = True)
df.head()
# Out:
#      sl   sw   pl   pw  flower_type
# 12  4.3  3.0  1.1  0.1  Iris-setosa
# 13  5.8  4.0  1.2  0.2  Iris-setosa
# 14  5.7  4.4  1.5  0.4  Iris-setosa
# 15  5.4  3.9  1.3  0.4  Iris-setosa
# 16  5.1  3.5  1.4  0.3  Iris-setosa

# %%
df[df.sl > 5]
# Out:
#       sl   sw   pl   pw     flower_type
# 13   5.8  4.0  1.2  0.2     Iris-setosa
# 14   5.7  4.4  1.5  0.4     Iris-setosa
# 15   5.4  3.9  1.3  0.4     Iris-setosa
# 16   5.1  3.5  1.4  0.3     Iris-setosa
# 17   5.7  3.8  1.7  0.3     Iris-setosa
# ..   ...  ...  ...  ...             ...
# 144  6.7  3.0  5.2  2.3  Iris-virginica
# 145  6.3  2.5  5.0  1.9  Iris-virginica
# 146  6.5  3.0  5.2  2.0  Iris-virginica
# 147  6.2  3.4  5.4  2.3  Iris-virginica
# 148  5.9  3.0  5.1  1.8  Iris-virginica
#
# [115 rows x 5 columns]

# %%
df[df.flower_type=='Iris-setosa'].describe()
# Out:
#               sl         sw         pl         pw
# count  37.000000  37.000000  37.000000  37.000000
# mean    5.045946   3.451351   1.464865   0.256757
# std     0.365600   0.403197   0.193242   0.114359
# min     4.300000   2.300000   1.000000   0.100000
# 25%     4.800000   3.200000   1.300000   0.200000
# 50%     5.100000   3.400000   1.500000   0.200000
# 75%     5.200000   3.700000   1.600000   0.300000
# max     5.800000   4.400000   1.900000   0.600000

# %%
df[df.flower_type == 'Iris-virginica'].describe()
# Out:
#              sl         sw         pl        pw
# count  50.00000  50.000000  50.000000  50.00000
# mean    6.58800   2.974000   5.552000   2.02600
# std     0.63588   0.322497   0.551895   0.27465
# min     4.90000   2.200000   4.500000   1.40000
# 25%     6.22500   2.800000   5.100000   1.80000
# 50%     6.50000   3.000000   5.550000   2.00000
# 75%     6.90000   3.175000   5.875000   2.30000
# max     7.90000   3.800000   6.900000   2.50000

# %%
# add a row
print(df.head())
print(df.iloc[0])
print(df.loc[15])
# Out:
#      sl   sw   pl   pw  flower_type
# 12  4.3  3.0  1.1  0.1  Iris-setosa
# 13  5.8  4.0  1.2  0.2  Iris-setosa
# 14  5.7  4.4  1.5  0.4  Iris-setosa
# 15  5.4  3.9  1.3  0.4  Iris-setosa
# 16  5.1  3.5  1.4  0.3  Iris-setosa
# sl                     4.3
# sw                       3
# pl                     1.1
# pw                     0.1
# flower_type    Iris-setosa
# Name: 12, dtype: object
# sl                     5.4
# sw                     3.9
# pl                     1.3
# pw                     0.4
# flower_type    Iris-setosa
# Name: 15, dtype: object

# %%
df.loc[149] = [1,2,3,4,"Iris-setosa"]

# %%
df.head()
# Out:
#      sl   sw   pl   pw  flower_type
# 12  4.3  3.0  1.1  0.1  Iris-setosa
# 13  5.8  4.0  1.2  0.2  Iris-setosa
# 14  5.7  4.4  1.5  0.4  Iris-setosa
# 15  5.4  3.9  1.3  0.4  Iris-setosa
# 16  5.1  3.5  1.4  0.3  Iris-setosa

# %%
df.tail()
# Out:
#       sl   sw   pl   pw     flower_type
# 146  6.5  3.0  5.2  2.0  Iris-virginica
# 147  6.2  3.4  5.4  2.3  Iris-virginica
# 148  5.9  3.0  5.1  1.8  Iris-virginica
# 0    1.0  2.0  3.0  4.0     Iris-setosa
# 149  1.0  2.0  3.0  4.0     Iris-setosa

# %%
coun1 = df[df.flower_type=='Iris-setosa']
print(len(coun1))
# Out:
# 39

# %%
df.reset_index(drop = True,inplace = True)

# %%
df
# Out:
#       sl   sw   pl   pw     flower_type
# 0    4.3  3.0  1.1  0.1     Iris-setosa
# 1    5.8  4.0  1.2  0.2     Iris-setosa
# 2    5.7  4.4  1.5  0.4     Iris-setosa
# 3    5.4  3.9  1.3  0.4     Iris-setosa
# 4    5.1  3.5  1.4  0.3     Iris-setosa
# ..   ...  ...  ...  ...             ...
# 134  6.5  3.0  5.2  2.0  Iris-virginica
# 135  6.2  3.4  5.4  2.3  Iris-virginica
# 136  5.9  3.0  5.1  1.8  Iris-virginica
# 137  1.0  2.0  3.0  4.0     Iris-setosa
# 138  1.0  2.0  3.0  4.0     Iris-setosa
#
# [139 rows x 5 columns]

# %%
df.index
# Out:
# RangeIndex(start=0, stop=139, step=1)

# %%
# removing the column
df.drop('sl',axis=1,inplace = True)

# %%
df
# Out:
#       sw   pl   pw     flower_type
# 0    3.0  1.1  0.1     Iris-setosa
# 1    4.0  1.2  0.2     Iris-setosa
# 2    4.4  1.5  0.4     Iris-setosa
# 3    3.9  1.3  0.4     Iris-setosa
# 4    3.5  1.4  0.3     Iris-setosa
# ..   ...  ...  ...             ...
# 134  3.0  5.2  2.0  Iris-virginica
# 135  3.4  5.4  2.3  Iris-virginica
# 136  3.0  5.1  1.8  Iris-virginica
# 137  2.0  3.0  4.0     Iris-setosa
# 138  2.0  3.0  4.0     Iris-setosa
#
# [139 rows x 4 columns]

# %%
df.describe()
# Out:
#                sw          pl          pw
# count  139.000000  139.000000  139.000000
# mean     3.013669    3.962590    1.331655
# std      0.450153    1.682186    0.794823
# min      2.000000    1.000000    0.100000
# 25%      2.750000    1.800000    0.450000
# 50%      3.000000    4.500000    1.400000
# 75%      3.250000    5.100000    1.900000
# max      4.400000    6.900000    4.000000

# %%
del df['sw']

# %%
df.describe()
# Out:
#                pl          pw
# count  139.000000  139.000000
# mean     3.962590    1.331655
# std      1.682186    0.794823
# min      1.000000    0.100000
# 25%      1.800000    0.450000
# 50%      4.500000    1.400000
# 75%      5.100000    1.900000
# max      6.900000    4.000000

# %%
df.head()
# Out:
#     pl   pw  flower_type
# 0  1.1  0.1  Iris-setosa
# 1  1.2  0.2  Iris-setosa
# 2  1.5  0.4  Iris-setosa
# 3  1.3  0.4  Iris-setosa
# 4  1.4  0.3  Iris-setosa

# %%
df = iris.copy()

# %%
df.describe()
df.columns = ['sl','sw','pl','pw','flower_type']

# %%
df
# Out:
#       sl   sw   pl   pw     flower_type
# 0    4.9  3.0  1.4  0.2     Iris-setosa
# 1    4.7  3.2  1.3  0.2     Iris-setosa
# 2    4.6  3.1  1.5  0.2     Iris-setosa
# 3    5.0  3.6  1.4  0.2     Iris-setosa
# 4    5.4  3.9  1.7  0.4     Iris-setosa
# ..   ...  ...  ...  ...             ...
# 144  6.7  3.0  5.2  2.3  Iris-virginica
# 145  6.3  2.5  5.0  1.9  Iris-virginica
# 146  6.5  3.0  5.2  2.0  Iris-virginica
# 147  6.2  3.4  5.4  2.3  Iris-virginica
# 148  5.9  3.0  5.1  1.8  Iris-virginica
#
# [149 rows x 5 columns]

# %%
# add a column

df.tail()
# Out:
#       sl   sw   pl   pw     flower_type
# 144  6.7  3.0  5.2  2.3  Iris-virginica
# 145  6.3  2.5  5.0  1.9  Iris-virginica
# 146  6.5  3.0  5.2  2.0  Iris-virginica
# 147  6.2  3.4  5.4  2.3  Iris-virginica
# 148  5.9  3.0  5.1  1.8  Iris-virginica

# %%
df['diff_pl_pw'] = df['pl']-df['pw']
df.tail()
# Out:
#       sl   sw   pl   pw     flower_type  diff_pl_pw
# 144  6.7  3.0  5.2  2.3  Iris-virginica         2.9
# 145  6.3  2.5  5.0  1.9  Iris-virginica         3.1
# 146  6.5  3.0  5.2  2.0  Iris-virginica         3.2
# 147  6.2  3.4  5.4  2.3  Iris-virginica         3.1
# 148  5.9  3.0  5.1  1.8  Iris-virginica         3.3

# %%
# dataframe which has some NaN entries
# 1) We can simply remove the rows with NaN or fill NaN


df.iloc[2:4,1:3] = np.nan

# %%
df
# Out:
#       sl   sw   pl   pw     flower_type  diff_pl_pw
# 0    4.9  3.0  1.4  0.2     Iris-setosa         1.2
# 1    4.7  3.2  1.3  0.2     Iris-setosa         1.1
# 2    4.6  NaN  NaN  0.2     Iris-setosa         1.3
# 3    5.0  NaN  NaN  0.2     Iris-setosa         1.2
# 4    5.4  3.9  1.7  0.4     Iris-setosa         1.3
# ..   ...  ...  ...  ...             ...         ...
# 144  6.7  3.0  5.2  2.3  Iris-virginica         2.9
# 145  6.3  2.5  5.0  1.9  Iris-virginica         3.1
# 146  6.5  3.0  5.2  2.0  Iris-virginica         3.2
# 147  6.2  3.4  5.4  2.3  Iris-virginica         3.1
# 148  5.9  3.0  5.1  1.8  Iris-virginica         3.3
#
# [149 rows x 6 columns]

# %%
df.describe()
# Out:
#                sl          sw          pl          pw  diff_pl_pw
# count  149.000000  147.000000  147.000000  149.000000  149.000000
# mean     5.848322    3.046939    3.806122    1.205369    2.569128
# std      0.828594    0.434048    1.750351    0.761292    1.047707
# min      4.300000    2.000000    1.000000    0.100000    0.800000
# 25%      5.100000    2.800000    1.600000    0.300000    1.400000
# 50%      5.800000    3.000000    4.400000    1.300000    2.900000
# 75%      6.400000    3.300000    5.100000    1.800000    3.300000
# max      7.900000    4.400000    6.900000    2.500000    4.700000

# %%
df.dropna(inplace = True) # dropping the rows completely

# %%
df.head()
df.reset_index(drop=True,inplace = True)

# %%
df.head()
# Out:
#     sl   sw   pl   pw  flower_type  diff_pl_pw
# 0  4.9  3.0  1.4  0.2  Iris-setosa         1.2
# 1  4.7  3.2  1.3  0.2  Iris-setosa         1.1
# 2  5.4  3.9  1.7  0.4  Iris-setosa         1.3
# 3  4.6  3.4  1.4  0.3  Iris-setosa         1.1
# 4  5.0  3.4  1.5  0.2  Iris-setosa         1.3

# %%
df.iloc[2:4,1:3] = np.nan

# %%
df
# Out:
#       sl   sw   pl   pw     flower_type  diff_pl_pw
# 0    4.9  3.0  1.4  0.2     Iris-setosa         1.2
# 1    4.7  3.2  1.3  0.2     Iris-setosa         1.1
# 2    5.4  NaN  NaN  NaN     Iris-setosa         1.3
# 3    4.6  NaN  NaN  NaN     Iris-setosa         1.1
# 4    5.0  3.4  1.5  0.2     Iris-setosa         1.3
# ..   ...  ...  ...  ...             ...         ...
# 142  6.7  3.0  5.2  2.3  Iris-virginica         2.9
# 143  6.3  2.5  5.0  1.9  Iris-virginica         3.1
# 144  6.5  3.0  5.2  2.0  Iris-virginica         3.2
# 145  6.2  3.4  5.4  2.3  Iris-virginica         3.1
# 146  5.9  3.0  5.1  1.8  Iris-virginica         3.3
#
# [147 rows x 6 columns]

# %%
df.sw.fillna(df.sw.mean(),inplace = True)
#df

# %%
df.head()
# Out:
#     sl        sw   pl   pw  flower_type  diff_pl_pw
# 0  4.9  3.000000  1.4  0.2  Iris-setosa         1.2
# 1  4.7  3.200000  1.3  0.2  Iris-setosa         1.1
# 2  5.4  3.038621  NaN  NaN  Iris-setosa         1.3
# 3  4.6  3.038621  NaN  NaN  Iris-setosa         1.1
# 4  5.0  3.400000  1.5  0.2  Iris-setosa         1.3

# %%
df.head()
# Out:
#     sl        sw   pl   pw  flower_type  diff_pl_pw
# 0  4.9  3.000000  1.4  0.2  Iris-setosa         1.2
# 1  4.7  3.200000  1.3  0.2  Iris-setosa         1.1
# 2  5.4  3.038621  NaN  NaN  Iris-setosa         1.3
# 3  4.6  3.038621  NaN  NaN  Iris-setosa         1.1
# 4  5.0  3.400000  1.5  0.2  Iris-setosa         1.3

# %%
df.sw.fillna(df.sw.mean())
# Out:
# 0      3.000000
# 1      3.200000
# 2      3.038621
# 3      3.038621
# 4      3.400000
#          ...
# 142    3.000000
# 143    2.500000
# 144    3.000000
# 145    3.400000
# 146    3.000000
# Name: sw, Length: 147, dtype: float64

# %%
df.pl.fillna(df.pl.mean(),inplace = True)
df.head()
# Out:
#     sl        sw        pl   pw  flower_type  diff_pl_pw
# 0  4.9  3.000000  1.400000  0.2  Iris-setosa         1.2
# 1  4.7  3.200000  1.300000  0.2  Iris-setosa         1.1
# 2  5.4  3.038621  3.837241  NaN  Iris-setosa         1.3
# 3  4.6  3.038621  3.837241  NaN  Iris-setosa         1.1
# 4  5.0  3.400000  1.500000  0.2  Iris-setosa         1.3

# %%
df.pw.fillna(df.pw.mean(),inplace = True)
df.head()
# Out:
#     sl        sw        pl        pw  flower_type  diff_pl_pw
# 0  4.9  3.000000  1.400000  0.200000  Iris-setosa         1.2
# 1  4.7  3.200000  1.300000  0.200000  Iris-setosa         1.1
# 2  5.4  3.038621  3.837241  1.231034  Iris-setosa         1.3
# 3  4.6  3.038621  3.837241  1.231034  Iris-setosa         1.1
# 4  5.0  3.400000  1.500000  0.200000  Iris-setosa         1.3

# %%
# handling strings in data-frame
df['Gender'] = "Female"

# %%
df.head()
# Out:
#     sl        sw        pl        pw  flower_type  diff_pl_pw  Gender
# 0  4.9  3.000000  1.400000  0.200000  Iris-setosa         1.2  Female
# 1  4.7  3.200000  1.300000  0.200000  Iris-setosa         1.1  Female
# 2  5.4  3.038621  3.837241  1.231034  Iris-setosa         1.3  Female
# 3  4.6  3.038621  3.837241  1.231034  Iris-setosa         1.1  Female
# 4  5.0  3.400000  1.500000  0.200000  Iris-setosa         1.3  Female

# %%
df.iloc[0:10,6] = "Male"

# %%
df.head()
# Out:
#     sl        sw        pl        pw  flower_type  diff_pl_pw Gender
# 0  4.9  3.000000  1.400000  0.200000  Iris-setosa         1.2   Male
# 1  4.7  3.200000  1.300000  0.200000  Iris-setosa         1.1   Male
# 2  5.4  3.038621  3.837241  1.231034  Iris-setosa         1.3   Male
# 3  4.6  3.038621  3.837241  1.231034  Iris-setosa         1.1   Male
# 4  5.0  3.400000  1.500000  0.200000  Iris-setosa         1.3   Male

# %%
df.tail()
# Out:
#       sl   sw   pl   pw     flower_type  diff_pl_pw  Gender
# 142  6.7  3.0  5.2  2.3  Iris-virginica         2.9  Female
# 143  6.3  2.5  5.0  1.9  Iris-virginica         3.1  Female
# 144  6.5  3.0  5.2  2.0  Iris-virginica         3.2  Female
# 145  6.2  3.4  5.4  2.3  Iris-virginica         3.1  Female
# 146  5.9  3.0  5.1  1.8  Iris-virginica         3.3  Female

# %%
def f(s):
    
    if s == 'Male':
        return 0
    else:
        return 1



df['gender_check'] = df.Gender.apply(f)

# %%
df.head()
# Out:
#     sl        sw        pl        pw  flower_type  diff_pl_pw Gender  \
# 0  4.9  3.000000  1.400000  0.200000  Iris-setosa         1.2   Male
# 1  4.7  3.200000  1.300000  0.200000  Iris-setosa         1.1   Male
# 2  5.4  3.038621  3.837241  1.231034  Iris-setosa         1.3   Male
# 3  4.6  3.038621  3.837241  1.231034  Iris-setosa         1.1   Male
# 4  5.0  3.400000  1.500000  0.200000  Iris-setosa         1.3   Male
#
#    gender_check
# 0             0
# 1             0
# 2             0
# 3             0
# 4             0

# %%
df.tail()
# Out:
#       sl   sw   pl   pw     flower_type  diff_pl_pw  Gender  gender_check
# 142  6.7  3.0  5.2  2.3  Iris-virginica         2.9  Female             1
# 143  6.3  2.5  5.0  1.9  Iris-virginica         3.1  Female             1
# 144  6.5  3.0  5.2  2.0  Iris-virginica         3.2  Female             1
# 145  6.2  3.4  5.4  2.3  Iris-virginica         3.1  Female             1
# 146  5.9  3.0  5.1  1.8  Iris-virginica         3.3  Female             1

# %%
del df['Gender']

# %%
df
# Out:
#       sl        sw        pl        pw     flower_type  diff_pl_pw  \
# 0    4.9  3.000000  1.400000  0.200000     Iris-setosa         1.2
# 1    4.7  3.200000  1.300000  0.200000     Iris-setosa         1.1
# 2    5.4  3.038621  3.837241  1.231034     Iris-setosa         1.3
# 3    4.6  3.038621  3.837241  1.231034     Iris-setosa         1.1
# 4    5.0  3.400000  1.500000  0.200000     Iris-setosa         1.3
# ..   ...       ...       ...       ...             ...         ...
# 142  6.7  3.000000  5.200000  2.300000  Iris-virginica         2.9
# 143  6.3  2.500000  5.000000  1.900000  Iris-virginica         3.1
# 144  6.5  3.000000  5.200000  2.000000  Iris-virginica         3.2
# 145  6.2  3.400000  5.400000  2.300000  Iris-virginica         3.1
# 146  5.9  3.000000  5.100000  1.800000  Iris-virginica         3.3
#
#      gender_check
# 0               0
# 1               0
# 2               0
# 3               0
# 4               0
# ..            ...
# 142             1
# ...
